# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tmdb_df = pd.read_csv('../../data/TMDB_tv_dataset_v3.csv')

# %%
tmdb_df
# Out:
#             id                  name  number_of_seasons  number_of_episodes  \
# 0         1399       Game of Thrones                  8                  73
# 1        71446           Money Heist                  3                  41
# 2        66732       Stranger Things                  4                  34
# 3         1402      The Walking Dead                 11                 177
# 4        63174               Lucifer                  6                  93
# ...        ...                   ...                ...                 ...
# 158561  235768              天罚-二战全纪实                  1                 100
# 158562  235767                 我们这一摊                  1                  13
# 158563  235766               山里来了熊孩子                  1                  13
# 158564  235765    开心超人联盟之勇敢之城1——棋兽传奇                  1                   6
# 158565   38212  Anhoniyon Ka Andhera                  0                   0
#
#        original_language  vote_count  vote_average  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
tmdb_df
# Out:
#             id                  name  number_of_seasons  number_of_episodes  \
# 0         1399       Game of Thrones                  8                  73
# 1        71446           Money Heist                  3                  41
# 2        66732       Stranger Things                  4                  34
# 3         1402      The Walking Dead                 11                 177
# 4        63174               Lucifer                  6                  93
# ...        ...                   ...                ...                 ...
# 158561  235768              天罚-二战全纪实                  1                 100
# 158562  235767                 我们这一摊                  1                  13
# 158563  235766               山里来了熊孩子                  1                  13
# 158564  235765    开心超人联盟之勇敢之城1——棋兽传奇                  1                   6
# 158565   38212  Anhoniyon Ka Andhera                  0                   0
#
#        original_language  vote_count  vote_average  \
# ...

# %%
tmdb_df=tmdb_df.drop(columns=['backdrop_path', 'homepage', 'poster_path'])
tmdb_df
# Out:
#             id                  name  number_of_seasons  number_of_episodes  \
# 0         1399       Game of Thrones                  8                  73
# 1        71446           Money Heist                  3                  41
# 2        66732       Stranger Things                  4                  34
# 3         1402      The Walking Dead                 11                 177
# 4        63174               Lucifer                  6                  93
# ...        ...                   ...                ...                 ...
# 158561  235768              天罚-二战全纪实                  1                 100
# 158562  235767                 我们这一摊                  1                  13
# 158563  235766               山里来了熊孩子                  1                  13
# 158564  235765    开心超人联盟之勇敢之城1——棋兽传奇                  1                   6
# 158565   38212  Anhoniyon Ka Andhera                  0                   0
#
#        original_language  vote_count  vote_average  \
# ...

# %%
tmdb_voteavg=tmdb_df.sort_values(by=['vote_average'], ascending=False)
tmdb_voteavg.head(5000)
# Out:
#            id                              name  number_of_seasons  \
# 47608  103628                   Адмиралы района                  2
# 51253  128917    Белка и Стрелка: Тайны космоса                  1
# 37581  212632                          Mørklagt                  1
# 37582   81486  Bug Juice: My Adventures at Camp                  1
# 23153  222838                         Колотушка                  1
# ...       ...                               ...                ...
# 42761  100870                            Tunnel                  1
# 42758   58290         The Magic of the Big Blue                  1
# 42757   58263                                O'                  8
# 49361     757                       Finger Tips                  0
# 42750   21765                      The Kagestar                  1
#
#        number_of_episodes original_language  vote_count  vote_average  \
# 47608                  36                ru           1          10.0
# ...

# %%
tmdb_topvoteavg = tmdb_df[tmdb_df['vote_average']==10.0]
tmdb_topvoteavg
# Out:
#             id                            name  number_of_seasons  \
# 5722    105696  Scooby-Doo!: Behind the Scenes                  1
# 8111    210805            Tyler Perry's Zatima                  3
# 10811    84274                        Delirium                  1
# 11063    93294               Dog's Most Wanted                  1
# 12198    71165                  Dateline on ID                 11
# ...        ...                             ...                ...
# 133986   62546               When We Go to War                  1
# 141129   76797                  Mai dire isola                  1
# 144271  201403                   My Money & Me                  1
# 147045  210051                    Hole in Love                  1
# 152497  207194                Court Night Live                  1
#
#         number_of_episodes original_language  vote_count  vote_average  \
# 5722                     8                en          34          10.0
# ...

# %% [markdown]
# ## 5221 have a average voter rating of 10.0

# %%
tmdb_noseasons = tmdb_df[tmdb_df['number_of_seasons']==0]
tmdb_noseasons
# Out:
#            id                   name  number_of_seasons  number_of_episodes  \
# 1972    20727             La Mentira                  0                   0
# 2451    33148  En Los Tacones De Eva                  0                   0
# 3338     2807            La Traición                  0                   0
# 3945    12889             Tú o nadie                  0                   0
# 4109     8067            Live XXX TV                  0                   0
# ...       ...                    ...                ...                 ...
# 158549  38214            Homemade TV                  0                   0
# 158550  38213     Sunday Pops Series                  0                   0
# 158552  38209     All Over the Place                  0                   0
# 158553  38208     All Star Glam Exam                  0                   0
# 158565  38212   Anhoniyon Ka Andhera                  0                   0
#
#        original_language  vote_count  vote_average  \
# ...

# %% [markdown]
# ## 22378 have no seasons. Not sure how that's a thing.

# %%
tmdb_noepisodes = tmdb_df[tmdb_df['number_of_episodes']==0]
tmdb_noepisodes
# Out:
#             id                                          name  \
# 1972     20727                                    La Mentira
# 2088    113558                        Pandillas guerra y paz
# 2451     33148                         En Los Tacones De Eva
# 3338      2807                                   La Traición
# 3945     12889                                    Tú o nadie
# ...        ...                                           ...
# 158550   38213                            Sunday Pops Series
# 158552   38209                            All Over the Place
# 158553   38208                            All Star Glam Exam
# 158555  235758  Alya Sometimes Hides Her Feelings in Russian
# 158565   38212                          Anhoniyon Ka Andhera
#
#         number_of_seasons  number_of_episodes original_language  vote_count  \
# 1972                    0                   0                es         178
# 2088                    1                   0                es         166
# ...

# %% [markdown]
# ## 23973 have no episodes.

# %%
tmdb_lang=tmdb_df.original_language.value_counts()
tmdb_lang
# Out:
# en    73638
# ja    13368
# zh    12469
# ko     7384
# fr     6926
#       ...
# sw        1
# st        1
# se        1
# mn        1
# aa        1
# Name: original_language, Length: 106, dtype: int64

# %% [markdown]
# ## 106 languages, english in first with 73638, japanese in second with 13368, and zh apparently means chinese which is third with 12469

# %%
tmdb_df.vote_count.describe()
# Out:
# count    158566.000000
# mean         14.144300
# std         196.746395
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max       21857.000000
# Name: vote_count, dtype: float64

# %%
tmdb_df.adult.value_counts()
# Out:
# False    156628
# True       1938
# Name: adult, dtype: int64

# %% [markdown]
# ## 1938 are categorized as adult shows

# %%
tmdb_df.number_of_seasons.value_counts()
# Out:
# 1      104943
# 0       22378
# 2       14015
# 3        5875
# 4        3194
#         ...
# 134         1
# 101         1
# 70          1
# 95          1
# 111         1
# Name: number_of_seasons, Length: 82, dtype: int64

# %%
tmdb_df[tmdb_df['number_of_seasons']==240]
# Out:
#         id           name  number_of_seasons  number_of_episodes  \
# 7088  6480  House Hunters                240                 804
#
#      original_language  vote_count  vote_average  \
# 7088                en          24           5.3
#
#                                                overview  adult first_air_date  \
# 7088  Hosted by Suzanne Whang, the show takes viewer...  False     1999-09-30
#
#      last_air_date  in_production  original_name  popularity     type  \
# 7088    2023-10-02           True  House Hunters       38.52  Reality
#
#                 status tagline   genres created_by languages networks  \
# 7088  Returning Series     NaN  Reality        NaN        en     HGTV
#
#      origin_country spoken_languages  production_companies  \
# 7088             US          English  Pie Town Productions
#
#           production_countries  episode_run_time
# 7088  United States of America                22

# %%
tmdb_df.number_of_seasons.describe()
# Out:
# count    158566.000000
# mean          1.566761
# std           3.005675
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max         240.000000
# Name: number_of_seasons, dtype: float64

# %% [markdown]
# ## House hunters has the most seasons with 240

# %%
tmdb_df.number_of_episodes.describe()
# Out:
# count    158566.000000
# mean         25.388084
# std         138.793401
# min           0.000000
# 25%           1.000000
# 50%           6.000000
# 75%          20.000000
# max       20839.000000
# Name: number_of_episodes, dtype: float64

# %%
tmdb_df[tmdb_df['number_of_episodes']==20839]
# Out:
#          id        name  number_of_seasons  number_of_episodes  \
# 2284  94722  Tagesschau                 72               20839
#
#      original_language  vote_count  vote_average  \
# 2284                de         145           7.5
#
#                                                overview  adult first_air_date  \
# 2284  German daily news program, the oldest still ex...  False     1952-12-26
#
#      last_air_date  in_production original_name  popularity  type  \
# 2284    2023-10-02           True    Tagesschau    3049.228  News
#
#                 status tagline genres created_by languages networks  \
# 2284  Returning Series     NaN   News        NaN        de      ARD
#
#      origin_country spoken_languages production_companies  \
# 2284             DE          Deutsch                  NDR
#
#      production_countries  episode_run_time
# 2284              Germany                15

# %% [markdown]
# ## A german daily news show called Tagesschau has the highest number of episodes with 20839. It has been on air since 1952.

# %%
tmdb_df.first_air_date.sort_values()
# Out:
# 32331     1917-01-09
# 118719    1921-01-01
# 55213     1936-11-03
# 40166     1938-07-12
# 45356     1938-08-01
#              ...
# 158550           NaN
# 158552           NaN
# 158553           NaN
# 158555           NaN
# 158565           NaN
# Name: first_air_date, Length: 158566, dtype: object

# %%
tmdb_df[tmdb_df['first_air_date']=='1917-01-09']
# Out:
#            id                                         name  number_of_seasons  \
# 32331  156597  B-Movies: Las obras maestras del cine cutre                  2
#
#        number_of_episodes original_language  vote_count  vote_average  \
# 32331                   1                es           2           8.0
#
#       overview  adult first_air_date last_air_date  in_production  \
# 32331      NaN  False     1917-01-09    1917-01-09           True
#
#                                      original_name  popularity      type  \
# 32331  B-Movies: Las obras maestras del cine cutre       0.613  Scripted
#
#                  status tagline       genres created_by languages  \
# 32331  Returning Series     NaN  Documentary        NaN       NaN
#
#             networks origin_country spoken_languages  \
# 32331  ARTE Creative             ES              NaN
#
#                    production_companies production_countries  episode_run_time
# ...

# %% [markdown]
# ## B-Movies: Las obras maestras del cine cutre is the earliest show with the first air date of January 9, 1917

# %%
tmdb_df.last_air_date.sort_values(ascending=False)
# Out:
# 81094     2023-10-03
# 45528     2023-10-03
# 113038    2023-10-03
# 92639     2023-10-03
# 118919    2023-10-03
#              ...
# 158550           NaN
# 158552           NaN
# 158553           NaN
# 158555           NaN
# 158565           NaN
# Name: last_air_date, Length: 158566, dtype: object

# %%
tmdb_df[tmdb_df['last_air_date']=='2023-10-03']
# Out:
#             id                                       name  number_of_seasons  \
# 2632    209265                             Land of Desire                  1
# 3051    215803                              Batang Quiapo                  2
# 4132    126929                         Welcome to Wrexham                  2
# 4306    226411                            Revenge is mine                  1
# 4412    229932      Pyaar Ka Pehla Adhyaya  - Shiv Shakti                  1
# ...        ...                                        ...                ...
# 158408  230518  Enquêtes  Paranormale de la rivière Grand                  1
# 158474  235781               The Vintage French Farmhouse                  1
# 158520  235777                                        Ира                  1
# 158535  235730                                My Precious                  1
# 158560  235769                                   Obituary                  1
#
# ...

# %% [markdown]
# ## There are 190 of them that are still airing as of October 3, 2023
